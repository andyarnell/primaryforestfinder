# %%
import os
import geopandas as gpd
import pandas as pd
from shapely import wkt
import math
import glob

def split_geopackage_to_csv(
    input_gpkg, 
    output_folder, 
    chunk_size=10000, 
    prefix="chunk", 
    columns=None
):
    """
    Splits a GeoPackage into multiple CSV files with WKT geometries.
    Skips chunks that already exist based on filename pattern.
    
    Parameters:
    -----------
    input_gpkg : str
        Path to the input GeoPackage file
    output_folder : str
        Folder to save the output CSV files
    chunk_size : int
        Number of rows per chunk
    prefix : str
        Prefix for output CSV files
    columns : list
        List of columns to include in output. If None, includes all columns
    """
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    try:
        # Read the GeoPackage
        print(f"Reading GeoPackage: {input_gpkg}")
        gdf = gpd.read_file(input_gpkg)
        
        # Get total number of rows
        total_rows = len(gdf)
        print(f"Total features: {total_rows}")
        
        # Calculate number of chunks
        num_chunks = math.ceil(total_rows / chunk_size)
        print(f"Splitting into {num_chunks} chunks of {chunk_size} rows each")
        
        # If columns specified, ensure 'geometry' is included
        if columns is not None and 'geometry' not in columns:
            columns.append('geometry')
            
        # Process each chunk
        for i in range(num_chunks):
            start_idx = i * chunk_size
            end_idx = min((i + 1) * chunk_size, total_rows)
            
            # Create output filename with row information
            output_file = os.path.join(output_folder, f"{prefix}_{start_idx}_to_{end_idx}_of_{total_rows}.csv")
            
            # Check if file already exists
            if os.path.exists(output_file):
                print(f"Chunk {i+1}/{num_chunks} (rows {start_idx} to {end_idx}) already exists - skipping")
                continue
                
            print(f"Processing chunk {i+1}/{num_chunks} (rows {start_idx} to {end_idx})")
            
            # Extract chunk
            chunk = gdf.iloc[start_idx:end_idx]
            
            # Filter columns if specified
            if columns is not None:
                chunk = chunk[columns]
                
            # Convert to DataFrame with WKT geometry
            df = pd.DataFrame(chunk)
            df['geometry'] = df['geometry'].apply(lambda x: x.wkt if x else "")
            
            # Save to CSV
            df.to_csv(output_file, index=False)
            print(f"Saved to {output_file}")
            
        print(f"Processing complete! {num_chunks} CSV files created in {output_folder}")
        
    except Exception as e:
        print(f"Error processing {input_gpkg}: {str(e)}")
        
def process_all_geopackages_in_folder(
    input_folder,
    output_folder,
    pattern="*_highways.gpkg",
    chunk_size=10000,
    columns=None
):
    """
    Process all geopackage files in a folder that match a pattern.
    Skips files where all chunks already exist.
    """
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    # Find all matching files
    search_pattern = os.path.join(input_folder, pattern)
    geopackage_files = glob.glob(search_pattern)
    
    if not geopackage_files:
        print(f"No files matching '{pattern}' found in {input_folder}")
        return
        
    print(f"Found {len(geopackage_files)} files to process")
    files_to_process = []
    
    # Check which files need processing by examining existing output chunks
    for gpkg_file in geopackage_files:
        filename = os.path.basename(gpkg_file)
        prefix = filename.replace("_highways.gpkg", "")
        
        # Look for existing chunks with this prefix
        existing_chunks = glob.glob(os.path.join(output_folder, f"{prefix}_*.csv"))
        
        # Skip processing if we've already created chunks for this file
        if existing_chunks:
            # Try to determine total rows from existing chunk filenames
            total_rows = None
            for chunk_path in existing_chunks:
                chunk_name = os.path.basename(chunk_path)
                if "_of_" in chunk_name:
                    try:
                        # Extract total rows from filename format: prefix_start_to_end_of_TOTAL.csv
                        total_part = chunk_name.split("_of_")[-1].replace(".csv", "")
                        total_rows = int(total_part)
                        break
                    except ValueError:
                        continue
            
            if total_rows:
                # Calculate expected number of chunks
                num_chunks = math.ceil(total_rows / chunk_size)
                
                # Check if all expected chunks exist
                all_chunks_exist = True
                for i in range(num_chunks):
                    start_idx = i * chunk_size
                    end_idx = min((i + 1) * chunk_size, total_rows)
                    output_file = os.path.join(output_folder, f"{prefix}_{start_idx}_to_{end_idx}_of_{total_rows}.csv")
                    
                    if not os.path.exists(output_file):
                        all_chunks_exist = False
                        break
                
                if all_chunks_exist:
                    print(f"Skipping {filename} - all {num_chunks} chunks already exist")
                    continue
        
        # If we get here, this file needs processing
        files_to_process.append(gpkg_file)
    
    print(f"Need to process {len(files_to_process)} of {len(geopackage_files)} files")
    
    # Process each file that needs processing
    for i, gpkg_file in enumerate(files_to_process):
        filename = os.path.basename(gpkg_file)
        prefix = filename.replace("_highways.gpkg", "")
        
        print(f"\nProcessing file {i+1}/{len(files_to_process)}: {filename}")
        print(f"Using prefix: {prefix}")
        
        # Process this file
        split_geopackage_to_csv(
            input_gpkg=gpkg_file,
            output_folder=output_folder,
            chunk_size=chunk_size,
            prefix=prefix,
            columns=columns
        )
        
    print(f"\nAll files processed! Check results in {output_folder}")

# %%
# in_folder = r"C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\roads\osm\osm_regional_250521"
# input_gpkg_name = "africa_highways.gpkg"
# input_gpkg_path = os.path.join(in_folder, input_gpkg_name)
# print (f"Input GeoPackage path: {input_gpkg_path}")

# %%
# Example usage
if __name__ == "__main__":
    # Path to your input folder with geopackages
    # in_folder = r"C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\roads\osm\osm_regional_250521"
    # in_folder = r"C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\roads\osm\osm_regional_250521\europe_gpkg"
    in_folder = r"C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521"
#    Where to save the CSV files

    # output_folder = os.path.join(in_folder, "geo_csvs")
    output_folder = r"C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs"

    patterns = [
        # "*_waterways.gpkg",
        "*_ferry_routes.gpkg",
        "*_boat_access.gpkg",
        "*_railways.gpkg",
        # "*_highways.gpkg"
    ]


    for pattern in patterns:
        # Ensure pattern is a string
        if not isinstance(pattern, str):
            raise ValueError(f"Pattern must be a string, got {type(pattern)}")
        # Ensure output_folder exists   
        if not os.path.exists(output_folder):
            print(f"Creating output folder: {output_folder}")
            os.makedirs(output_folder, exist_ok=True)    

        # For each pattern, process all matching geopackages
        print(f"Processing pattern: {patterns}")
        # Process all files matching the pattern
        process_all_geopackages_in_folder(
            input_folder=in_folder,
            output_folder=output_folder,
            pattern=pattern,
            chunk_size=10000000,
        )
            # columns=['osm_id', 'highway', 'geometry']
    #     )
    # # Process all files
    # process_all_geopackages_in_folder(
    #     input_folder=in_folder,
    #     output_folder=output_folder,
    #     pattern="*_highways.gpkg",
    #     chunk_size=10000000,
    #     # columns=['osm_id', 'highway', 'geometry']
    # )
# Out:
# Processing pattern: ['*_waterways.gpkg', '*_ferry_routes.gpkg', '*_boat_access.gpkg', '*_railways.gpkg']
# Found 57 files to process
# Skipping albania_waterways.gpkg - all 1 chunks already exist
# Skipping andorra_waterways.gpkg - all 1 chunks already exist
# Skipping austria_waterways.gpkg - all 1 chunks already exist
# Skipping azores_waterways.gpkg - all 1 chunks already exist
# Skipping belarus_waterways.gpkg - all 1 chunks already exist
# Skipping belgium_waterways.gpkg - all 1 chunks already exist
# Skipping bosnia_herzegovina_waterways.gpkg - all 1 chunks already exist
# Skipping bulgaria_waterways.gpkg - all 1 chunks already exist
# Skipping croatia_waterways.gpkg - all 1 chunks already exist
# Skipping cyprus_waterways.gpkg - all 1 chunks already exist
# Skipping czech_republic_waterways.gpkg - all 1 chunks already exist
# Skipping denmark_waterways.gpkg - all 1 chunks already exist
# Skipping estonia_waterways.gpkg - all 1 chunks already exist
# Skipping faroe_islands_waterways.gpkg - all 1 chunks already exist
# Skipping finland_waterways.gpkg - all 1 chunks already exist
# Skipping france_waterways.gpkg - all 1 chunks already exist
# Skipping georgia_waterways.gpkg - all 1 chunks already exist
# Skipping germany_waterways.gpkg - all 1 chunks already exist
# Skipping greece_waterways.gpkg - all 1 chunks already exist
# Skipping guernsey_jersey_waterways.gpkg - all 1 chunks already exist
# Skipping hungary_waterways.gpkg - all 1 chunks already exist
# Skipping iceland_waterways.gpkg - all 1 chunks already exist
# Skipping ireland_and_northern_ireland_waterways.gpkg - all 1 chunks already exist
# Skipping isle_of_man_waterways.gpkg - all 1 chunks already exist
# Skipping italy_waterways.gpkg - all 1 chunks already exist
# Skipping kosovo_waterways.gpkg - all 1 chunks already exist
# Skipping latvia_waterways.gpkg - all 1 chunks already exist
# Skipping liechtenstein_waterways.gpkg - all 1 chunks already exist
# Skipping lithuania_waterways.gpkg - all 1 chunks already exist
# Skipping luxembourg_waterways.gpkg - all 1 chunks already exist
# Skipping macedonia_waterways.gpkg - all 1 chunks already exist
# Skipping malta_waterways.gpkg - all 1 chunks already exist
# Skipping moldova_waterways.gpkg - all 1 chunks already exist
# Skipping monaco_waterways.gpkg - all 1 chunks already exist
# Skipping montenegro_waterways.gpkg - all 1 chunks already exist
# Skipping netherlands_waterways.gpkg - all 1 chunks already exist
# Skipping norway_waterways.gpkg - all 1 chunks already exist
# Skipping poland_waterways.gpkg - all 1 chunks already exist
# Skipping portugal_waterways.gpkg - all 1 chunks already exist
# Skipping romania_waterways.gpkg - all 1 chunks already exist
# Skipping russia_waterways.gpkg - all 1 chunks already exist
# Skipping serbia_waterways.gpkg - all 1 chunks already exist
# Skipping slovakia_waterways.gpkg - all 1 chunks already exist
# Skipping slovenia_waterways.gpkg - all 1 chunks already exist
# Skipping spain_waterways.gpkg - all 1 chunks already exist
# Skipping sweden_waterways.gpkg - all 1 chunks already exist
# Skipping switzerland_waterways.gpkg - all 1 chunks already exist
# Skipping turkey_waterways.gpkg - all 1 chunks already exist
# Skipping ukraine_waterways.gpkg - all 1 chunks already exist
# Skipping united_kingdom_waterways.gpkg - all 1 chunks already exist
# Need to process 7 of 57 files
#
# Processing file 1/7: africa_waterways.gpkg
# Using prefix: africa_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\africa_waterways.gpkg
# Total features: 1411269
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 1411269)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\africa_waterways.gpkg_0_to_1411269_of_1411269.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 2/7: antarctica_waterways.gpkg
# Using prefix: antarctica_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\antarctica_waterways.gpkg
# Total features: 5409
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 5409)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\antarctica_waterways.gpkg_0_to_5409_of_5409.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 3/7: asia_waterways.gpkg
# Using prefix: asia_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\asia_waterways.gpkg
# Total features: 3930225
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 3930225)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\asia_waterways.gpkg_0_to_3930225_of_3930225.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 4/7: australia_oceania_waterways.gpkg
# Using prefix: australia_oceania_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\australia_oceania_waterways.gpkg
# Total features: 668070
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 668070)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\australia_oceania_waterways.gpkg_0_to_668070_of_668070.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 5/7: central_america_waterways.gpkg
# Using prefix: central_america_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\central_america_waterways.gpkg
# Total features: 191587
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 191587)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\central_america_waterways.gpkg_0_to_191587_of_191587.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 6/7: north_america_waterways.gpkg
# Using prefix: north_america_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\north_america_waterways.gpkg
# Total features: 16896334
# Splitting into 2 chunks of 10000000 rows each
# Processing chunk 1/2 (rows 0 to 10000000)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\north_america_waterways.gpkg_0_to_10000000_of_16896334.csv
# Processing chunk 2/2 (rows 10000000 to 16896334)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\north_america_waterways.gpkg_10000000_to_16896334_of_16896334.csv
# Processing complete! 2 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 7/7: south_america_waterways.gpkg
# Using prefix: south_america_waterways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\south_america_waterways.gpkg
# Total features: 2100960
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 2100960)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\south_america_waterways.gpkg_0_to_2100960_of_2100960.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# All files processed! Check results in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
# Processing pattern: ['*_waterways.gpkg', '*_ferry_routes.gpkg', '*_boat_access.gpkg', '*_railways.gpkg']
# Found 54 files to process
# Skipping albania_ferry_routes.gpkg - all 1 chunks already exist
# Skipping austria_ferry_routes.gpkg - all 1 chunks already exist
# Skipping azores_ferry_routes.gpkg - all 1 chunks already exist
# Skipping belarus_ferry_routes.gpkg - all 1 chunks already exist
# Skipping belgium_ferry_routes.gpkg - all 1 chunks already exist
# Skipping bosnia_herzegovina_ferry_routes.gpkg - all 1 chunks already exist
# Skipping bulgaria_ferry_routes.gpkg - all 1 chunks already exist
# Skipping croatia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping cyprus_ferry_routes.gpkg - all 1 chunks already exist
# Skipping czech_republic_ferry_routes.gpkg - all 1 chunks already exist
# Skipping denmark_ferry_routes.gpkg - all 1 chunks already exist
# Skipping estonia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping faroe_islands_ferry_routes.gpkg - all 1 chunks already exist
# Skipping finland_ferry_routes.gpkg - all 1 chunks already exist
# Skipping france_ferry_routes.gpkg - all 1 chunks already exist
# Skipping georgia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping germany_ferry_routes.gpkg - all 1 chunks already exist
# Skipping greece_ferry_routes.gpkg - all 1 chunks already exist
# Skipping guernsey_jersey_ferry_routes.gpkg - all 1 chunks already exist
# Skipping hungary_ferry_routes.gpkg - all 1 chunks already exist
# Skipping iceland_ferry_routes.gpkg - all 1 chunks already exist
# Skipping ireland_and_northern_ireland_ferry_routes.gpkg - all 1 chunks already exist
# Skipping isle_of_man_ferry_routes.gpkg - all 1 chunks already exist
# Skipping italy_ferry_routes.gpkg - all 1 chunks already exist
# Skipping latvia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping lithuania_ferry_routes.gpkg - all 1 chunks already exist
# Skipping luxembourg_ferry_routes.gpkg - all 1 chunks already exist
# Skipping macedonia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping malta_ferry_routes.gpkg - all 1 chunks already exist
# Skipping moldova_ferry_routes.gpkg - all 1 chunks already exist
# Skipping monaco_ferry_routes.gpkg - all 1 chunks already exist
# Skipping montenegro_ferry_routes.gpkg - all 1 chunks already exist
# Skipping netherlands_ferry_routes.gpkg - all 1 chunks already exist
# Skipping norway_ferry_routes.gpkg - all 1 chunks already exist
# Skipping poland_ferry_routes.gpkg - all 1 chunks already exist
# Skipping portugal_ferry_routes.gpkg - all 1 chunks already exist
# Skipping romania_ferry_routes.gpkg - all 1 chunks already exist
# Skipping russia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping serbia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping slovakia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping slovenia_ferry_routes.gpkg - all 1 chunks already exist
# Skipping spain_ferry_routes.gpkg - all 1 chunks already exist
# Skipping sweden_ferry_routes.gpkg - all 1 chunks already exist
# Skipping switzerland_ferry_routes.gpkg - all 1 chunks already exist
# Skipping turkey_ferry_routes.gpkg - all 1 chunks already exist
# Skipping ukraine_ferry_routes.gpkg - all 1 chunks already exist
# Skipping united_kingdom_ferry_routes.gpkg - all 1 chunks already exist
# Need to process 7 of 54 files
#
# Processing file 1/7: africa_ferry_routes.gpkg
# Using prefix: africa_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\africa_ferry_routes.gpkg
# Total features: 2617
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 2617)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\africa_ferry_routes.gpkg_0_to_2617_of_2617.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 2/7: antarctica_ferry_routes.gpkg
# Using prefix: antarctica_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\antarctica_ferry_routes.gpkg
# Total features: 3
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 3)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\antarctica_ferry_routes.gpkg_0_to_3_of_3.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 3/7: asia_ferry_routes.gpkg
# Using prefix: asia_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\asia_ferry_routes.gpkg
# Total features: 13648
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 13648)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\asia_ferry_routes.gpkg_0_to_13648_of_13648.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 4/7: australia_oceania_ferry_routes.gpkg
# Using prefix: australia_oceania_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\australia_oceania_ferry_routes.gpkg
# Total features: 743
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 743)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\australia_oceania_ferry_routes.gpkg_0_to_743_of_743.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 5/7: central_america_ferry_routes.gpkg
# Using prefix: central_america_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\central_america_ferry_routes.gpkg
# Total features: 520
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 520)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\central_america_ferry_routes.gpkg_0_to_520_of_520.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 6/7: north_america_ferry_routes.gpkg
# Using prefix: north_america_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\north_america_ferry_routes.gpkg
# Total features: 1363
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 1363)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\north_america_ferry_routes.gpkg_0_to_1363_of_1363.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 7/7: south_america_ferry_routes.gpkg
# Using prefix: south_america_ferry_routes.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\south_america_ferry_routes.gpkg
# Total features: 2183
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 2183)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\south_america_ferry_routes.gpkg_0_to_2183_of_2183.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# All files processed! Check results in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
# Processing pattern: ['*_waterways.gpkg', '*_ferry_routes.gpkg', '*_boat_access.gpkg', '*_railways.gpkg']
# Found 56 files to process
# Skipping albania_boat_access.gpkg - all 1 chunks already exist
# Skipping austria_boat_access.gpkg - all 1 chunks already exist
# Skipping azores_boat_access.gpkg - all 1 chunks already exist
# Skipping belarus_boat_access.gpkg - all 1 chunks already exist
# Skipping belgium_boat_access.gpkg - all 1 chunks already exist
# Skipping bosnia_herzegovina_boat_access.gpkg - all 1 chunks already exist
# Skipping bulgaria_boat_access.gpkg - all 1 chunks already exist
# Skipping croatia_boat_access.gpkg - all 1 chunks already exist
# Skipping cyprus_boat_access.gpkg - all 1 chunks already exist
# Skipping czech_republic_boat_access.gpkg - all 1 chunks already exist
# Skipping denmark_boat_access.gpkg - all 1 chunks already exist
# Skipping estonia_boat_access.gpkg - all 1 chunks already exist
# Skipping faroe_islands_boat_access.gpkg - all 1 chunks already exist
# Skipping finland_boat_access.gpkg - all 1 chunks already exist
# Skipping france_boat_access.gpkg - all 1 chunks already exist
# Skipping georgia_boat_access.gpkg - all 1 chunks already exist
# Skipping germany_boat_access.gpkg - all 1 chunks already exist
# Skipping greece_boat_access.gpkg - all 1 chunks already exist
# Skipping guernsey_jersey_boat_access.gpkg - all 1 chunks already exist
# Skipping hungary_boat_access.gpkg - all 1 chunks already exist
# Skipping iceland_boat_access.gpkg - all 1 chunks already exist
# Skipping ireland_and_northern_ireland_boat_access.gpkg - all 1 chunks already exist
# Skipping isle_of_man_boat_access.gpkg - all 1 chunks already exist
# Skipping italy_boat_access.gpkg - all 1 chunks already exist
# Skipping kosovo_boat_access.gpkg - all 1 chunks already exist
# Skipping latvia_boat_access.gpkg - all 1 chunks already exist
# Skipping liechtenstein_boat_access.gpkg - all 1 chunks already exist
# Skipping lithuania_boat_access.gpkg - all 1 chunks already exist
# Skipping luxembourg_boat_access.gpkg - all 1 chunks already exist
# Skipping macedonia_boat_access.gpkg - all 1 chunks already exist
# Skipping malta_boat_access.gpkg - all 1 chunks already exist
# Skipping moldova_boat_access.gpkg - all 1 chunks already exist
# Skipping monaco_boat_access.gpkg - all 1 chunks already exist
# Skipping montenegro_boat_access.gpkg - all 1 chunks already exist
# Skipping netherlands_boat_access.gpkg - all 1 chunks already exist
# Skipping norway_boat_access.gpkg - all 1 chunks already exist
# Skipping poland_boat_access.gpkg - all 1 chunks already exist
# Skipping portugal_boat_access.gpkg - all 1 chunks already exist
# Skipping romania_boat_access.gpkg - all 1 chunks already exist
# Skipping russia_boat_access.gpkg - all 1 chunks already exist
# Skipping serbia_boat_access.gpkg - all 1 chunks already exist
# Skipping slovakia_boat_access.gpkg - all 1 chunks already exist
# Skipping slovenia_boat_access.gpkg - all 1 chunks already exist
# Skipping spain_boat_access.gpkg - all 1 chunks already exist
# Skipping sweden_boat_access.gpkg - all 1 chunks already exist
# Skipping switzerland_boat_access.gpkg - all 1 chunks already exist
# Skipping turkey_boat_access.gpkg - all 1 chunks already exist
# Skipping ukraine_boat_access.gpkg - all 1 chunks already exist
# Skipping united_kingdom_boat_access.gpkg - all 1 chunks already exist
# Need to process 7 of 56 files
#
# Processing file 1/7: africa_boat_access.gpkg
# Using prefix: africa_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\africa_boat_access.gpkg
# Total features: 11169
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 11169)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\africa_boat_access.gpkg_0_to_11169_of_11169.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 2/7: antarctica_boat_access.gpkg
# Using prefix: antarctica_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\antarctica_boat_access.gpkg
# Total features: 13
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 13)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\antarctica_boat_access.gpkg_0_to_13_of_13.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 3/7: asia_boat_access.gpkg
# Using prefix: asia_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\asia_boat_access.gpkg
# Total features: 87841
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 87841)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\asia_boat_access.gpkg_0_to_87841_of_87841.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 4/7: australia_oceania_boat_access.gpkg
# Using prefix: australia_oceania_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\australia_oceania_boat_access.gpkg
# Total features: 29510
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 29510)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\australia_oceania_boat_access.gpkg_0_to_29510_of_29510.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 5/7: central_america_boat_access.gpkg
# Using prefix: central_america_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\central_america_boat_access.gpkg
# Total features: 15391
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 15391)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\central_america_boat_access.gpkg_0_to_15391_of_15391.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 6/7: north_america_boat_access.gpkg
# Using prefix: north_america_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\north_america_boat_access.gpkg
# Total features: 211849
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 211849)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\north_america_boat_access.gpkg_0_to_211849_of_211849.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 7/7: south_america_boat_access.gpkg
# Using prefix: south_america_boat_access.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\south_america_boat_access.gpkg
# Total features: 18425
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 18425)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\south_america_boat_access.gpkg_0_to_18425_of_18425.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# All files processed! Check results in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
# Processing pattern: ['*_waterways.gpkg', '*_ferry_routes.gpkg', '*_boat_access.gpkg', '*_railways.gpkg']
# Found 54 files to process
# Skipping albania_railways.gpkg - all 1 chunks already exist
# Skipping austria_railways.gpkg - all 1 chunks already exist
# Skipping belarus_railways.gpkg - all 1 chunks already exist
# Skipping belgium_railways.gpkg - all 1 chunks already exist
# Skipping bosnia_herzegovina_railways.gpkg - all 1 chunks already exist
# Skipping bulgaria_railways.gpkg - all 1 chunks already exist
# Skipping croatia_railways.gpkg - all 1 chunks already exist
# Skipping cyprus_railways.gpkg - all 1 chunks already exist
# Skipping czech_republic_railways.gpkg - all 1 chunks already exist
# Skipping denmark_railways.gpkg - all 1 chunks already exist
# Skipping estonia_railways.gpkg - all 1 chunks already exist
# Skipping faroe_islands_railways.gpkg - all 1 chunks already exist
# Skipping finland_railways.gpkg - all 1 chunks already exist
# Skipping france_railways.gpkg - all 1 chunks already exist
# Skipping georgia_railways.gpkg - all 1 chunks already exist
# Skipping germany_railways.gpkg - all 1 chunks already exist
# Skipping greece_railways.gpkg - all 1 chunks already exist
# Skipping guernsey_jersey_railways.gpkg - all 1 chunks already exist
# Skipping hungary_railways.gpkg - all 1 chunks already exist
# Skipping iceland_railways.gpkg - all 1 chunks already exist
# Skipping ireland_and_northern_ireland_railways.gpkg - all 1 chunks already exist
# Skipping isle_of_man_railways.gpkg - all 1 chunks already exist
# Skipping italy_railways.gpkg - all 1 chunks already exist
# Skipping kosovo_railways.gpkg - all 1 chunks already exist
# Skipping latvia_railways.gpkg - all 1 chunks already exist
# Skipping liechtenstein_railways.gpkg - all 1 chunks already exist
# Skipping lithuania_railways.gpkg - all 1 chunks already exist
# Skipping luxembourg_railways.gpkg - all 1 chunks already exist
# Skipping macedonia_railways.gpkg - all 1 chunks already exist
# Skipping malta_railways.gpkg - all 1 chunks already exist
# Skipping moldova_railways.gpkg - all 1 chunks already exist
# Skipping monaco_railways.gpkg - all 1 chunks already exist
# Skipping montenegro_railways.gpkg - all 1 chunks already exist
# Skipping netherlands_railways.gpkg - all 1 chunks already exist
# Skipping norway_railways.gpkg - all 1 chunks already exist
# Skipping poland_railways.gpkg - all 1 chunks already exist
# Skipping portugal_railways.gpkg - all 1 chunks already exist
# Skipping romania_railways.gpkg - all 1 chunks already exist
# Skipping russia_railways.gpkg - all 1 chunks already exist
# Skipping serbia_railways.gpkg - all 1 chunks already exist
# Skipping slovakia_railways.gpkg - all 1 chunks already exist
# Skipping slovenia_railways.gpkg - all 1 chunks already exist
# Skipping spain_railways.gpkg - all 1 chunks already exist
# Skipping sweden_railways.gpkg - all 1 chunks already exist
# Skipping switzerland_railways.gpkg - all 1 chunks already exist
# Skipping turkey_railways.gpkg - all 1 chunks already exist
# Skipping ukraine_railways.gpkg - all 1 chunks already exist
# Skipping united_kingdom_railways.gpkg - all 1 chunks already exist
# Need to process 6 of 54 files
#
# Processing file 1/6: africa_railways.gpkg
# Using prefix: africa_railways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\africa_railways.gpkg
# Total features: 91936
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 91936)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\africa_railways.gpkg_0_to_91936_of_91936.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 2/6: asia_railways.gpkg
# Using prefix: asia_railways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\asia_railways.gpkg
# Total features: 1092497
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 1092497)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\asia_railways.gpkg_0_to_1092497_of_1092497.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 3/6: australia_oceania_railways.gpkg
# Using prefix: australia_oceania_railways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\australia_oceania_railways.gpkg
# Total features: 79643
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 79643)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\australia_oceania_railways.gpkg_0_to_79643_of_79643.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 4/6: central_america_railways.gpkg
# Using prefix: central_america_railways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\central_america_railways.gpkg
# Total features: 11223
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 11223)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\central_america_railways.gpkg_0_to_11223_of_11223.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 5/6: north_america_railways.gpkg
# Using prefix: north_america_railways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\north_america_railways.gpkg
# Total features: 707393
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 707393)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\north_america_railways.gpkg_0_to_707393_of_707393.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# Processing file 6/6: south_america_railways.gpkg
# Using prefix: south_america_railways.gpkg
# Reading GeoPackage: C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521\south_america_railways.gpkg
# Total features: 75303
# Splitting into 1 chunks of 10000000 rows each
# Processing chunk 1/1 (rows 0 to 75303)
# Saved to C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs\south_america_railways.gpkg_0_to_75303_of_75303.csv
# Processing complete! 1 CSV files created in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
#
# All files processed! Check results in C:\Users\Arnell\OneDrive - Food and Agriculture Organization\project_work\p0002_primary_forest_support\work_in_progress\osm_extracts\osm_regional_250521_geo_csvs
